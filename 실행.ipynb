# %%
import subprocess
import sys
from pathlib import Path

APP_PATH = Path.cwd() / "app.py"

process = subprocess.Popen([
    sys.executable,
    "-m",
    "streamlit",
    "run",
    str(APP_PATH)
])

print("LOGI-COPILOT 실행 완료")
print("브라우저가 자동으로 열리지 않으면 아래 주소로 접속하세요.")
print("http://localhost:8501")
